# %%
import pandas as pd

# %%
#reading CSV
df=pd.read_csv("C:/Users/deevy/Desktop/fifa.csv")
df.head()
# Out:
#    Unnamed: 0  sofifa_id                                         player_url  \
# 0           0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1           1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3           3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4           4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
#
# ...

# %%
#making a copy of the dataframe
df1=df.copy()

# %%
#dropping columns
df1=df1.drop(columns=["Unnamed: 0","sofifa_id","player_url","long_name","dob","mentality_composure"])

# %%
df1.head()
# Out:
#           short_name  age  height_cm  weight_kg  nationality  \
# 0           L. Messi   27        169         67    Argentina
# 1  Cristiano Ronaldo   29        185         80     Portugal
# 2          A. Robben   30        180         80  Netherlands
# 3     Z. Ibrahimović   32        195         95       Sweden
# 4           M. Neuer   28        193         92      Germany
#
#              club_name             league_name  league_rank  overall  \
# 0         FC Barcelona  Spain Primera Division          1.0       93
# 1          Real Madrid  Spain Primera Division          1.0       92
# 2    FC Bayern München    German 1. Bundesliga          1.0       90
# 3  Paris Saint-Germain          French Ligue 1          1.0       90
# 4    FC Bayern München    German 1. Bundesliga          1.0       90
#
#    potential  ...  mentality_vision  mentality_penalties defending_marking  \
# 0         95  ...                90                   76                25
# ...

# %%
#generate a summary of statistics
df1.describe()
# Out:
#                 age     height_cm     weight_kg   league_rank       overall  \
# count  16155.000000  16155.000000  16155.000000  15916.000000  16155.000000
# mean      24.776230    181.083627     75.474342      1.378424     63.830393
# std        4.625321      6.618974      6.891796      0.736796      7.169896
# min       16.000000    155.000000     50.000000      1.000000     40.000000
# 25%       21.000000    176.000000     70.000000      1.000000     59.000000
# 50%       24.000000    181.000000     75.000000      1.000000     64.000000
# 75%       28.000000    186.000000     80.000000      2.000000     68.000000
# max       44.000000    204.000000    110.000000      4.000000     93.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  16155.000000  1.615500e+04   16155.000000              16155.000000
# mean      68.350108  1.060882e+06   13056.453110                  1.122501
# ...

# %%
#gives general summary of the DataFrame
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16155 entries, 0 to 16154
# Data columns (total 75 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   short_name                  16155 non-null  object
#  1   age                         16155 non-null  int64
#  2   height_cm                   16155 non-null  int64
#  3   weight_kg                   16155 non-null  int64
#  4   nationality                 16155 non-null  object
#  5   club_name                   15916 non-null  object
#  6   league_name                 15916 non-null  object
#  7   league_rank                 15916 non-null  float64
#  8   overall                     16155 non-null  int64
#  9   potential                   16155 non-null  int64
#  10  value_eur                   16155 non-null  int64
#  11  wage_eur                    16155 non-null  int64
#  12  player_positions            16155 non-null  object
# ...

# %%
#used to create different types of plots such as line, bar, box, area, scatter etc
#various options available to customize theses plots

df1['age'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
#to select rows and columns by their index
df1.iloc[:]
# Out:
#               short_name  age  height_cm  weight_kg  nationality  \
# 0               L. Messi   27        169         67    Argentina
# 1      Cristiano Ronaldo   29        185         80     Portugal
# 2              A. Robben   30        180         80  Netherlands
# 3         Z. Ibrahimović   32        195         95       Sweden
# 4               M. Neuer   28        193         92      Germany
# ...                  ...  ...        ...        ...          ...
# 16150          E. Redman   17        187         81        Wales
# 16151         A. Collins   17        178         57        Wales
# 16152           P. Żemło   18        190         76       Poland
# 16153          T. Davies   22        180         70      England
# 16154         P. Tisdale   41        175         72        Malta
#
#                  club_name                  league_name  league_rank  overall  \
# 0             FC Barcelona       Spain Primera Division          1.0       93
# ...

# %%
#sample allows you to randomly select rows from a data frame
df1.sample()
# Out:
#      short_name  age  height_cm  weight_kg nationality  club_name  \
# 4153   J. Rojas   25        173         65     Ecuador  Cruz Azul
#
#           league_name  league_rank  overall  potential  ...  mentality_vision  \
# 4153  Mexican Liga MX          1.0       68         73  ...                62
#
#       mentality_penalties defending_marking defending_standing_tackle  \
# 4153                   65                25                        25
#
#       defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 4153                        25                   6                    11
#
#      goalkeeping_kicking goalkeeping_positioning goalkeeping_reflexes
# 4153                  14                       9                   11
#
# [1 rows x 75 columns]

# %%
#reutrns a data frame of same size as the the df in use, with True or False indicating wheteher a value is missing or not
df1.isnull()
# Out:
#        short_name    age  height_cm  weight_kg  nationality  club_name  \
# 0           False  False      False      False        False      False
# 1           False  False      False      False        False      False
# 2           False  False      False      False        False      False
# 3           False  False      False      False        False      False
# 4           False  False      False      False        False      False
# ...           ...    ...        ...        ...          ...        ...
# 16150       False  False      False      False        False      False
# 16151       False  False      False      False        False      False
# 16152       False  False      False      False        False      False
# 16153       False  False      False      False        False      False
# 16154       False  False      False      False        False      False
#
#        league_name  league_rank  overall  potential  ...  mentality_vision  \
# ...

# %%
#df.fillna is used to fill in missing values in a dataframe

# %%
#df.dropna() is used to remove null values from a dataframe

# %%
#df.merge is used to merge two dataframes

# %%
#df.rename is used to change the name of columns

# %%
#df.to_csv() is used to export a data frame to a CSV

# %%
#to find duplicates
df1.duplicated().sum()
# Out:
# 0

# %%
df1.nunique()
# Out:
# short_name                 15195
# age                           29
# height_cm                     48
# weight_kg                     54
# nationality                  149
#                            ...
# goalkeeping_diving            73
# goalkeeping_handling          73
# goalkeeping_kicking           74
# goalkeeping_positioning       74
# goalkeeping_reflexes          74
# Length: 75, dtype: int64

# %%
#gives shape of the Data frame
df1.shape
# Out:
# (16155, 75)
